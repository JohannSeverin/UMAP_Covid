# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
url_confirmed_us = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv'
url_deaths_us = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv'
url_confirmed_global = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
url_deaths_global = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'
url_recovered_global = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv'


# Import urls as dataframes

confirmed_dat = pd.read_csv(url_confirmed_global)
deaths_dat = pd.read_csv(url_deaths_global)

deaths_dat = confirmed_dat

deaths_dat.set_index("Country/Region", inplace = True)
deaths_dat = deaths_dat.loc[~deaths_dat.index.duplicated(keep='first')]


deaths_set = deaths_dat.iloc[:, 4:]

# %%
cop = deaths_set.copy()
sums = np.sum(deaths_set,axis = 1)
maxes = np.max(deaths_set, axis = 1)
for ind in deaths_set.index:
    if maxes[ind] > 10:
        cop.loc[ind, :] /= sums[ind]
    else:
        cop.loc[ind, :] = np.zeros(len(cop.loc[ind, :]))

# %%
df = np.array(cop)

# %%
dist = lambda i, j: np.sum(np.square(df[i, :] - df[j, :]))

def dist(i, j):
    l = len(np.square(df[i, :]))
    i_arr = np.hstack([df[i, :], np.zeros(l)])
    i_2d_arr = np.array([np.roll(i_arr, shift = a) for a in range(l)])
    j_arr = np.hstack([df[j, :], np.zeros(l)])
    return np.min(np.sum(np.square(i_2d_arr - j_arr), axis = 1))
    

mat = np.zeros((df.shape[0], df.shape[0]))
for i in range(df.shape[0]):
    for j in range(df.shape[0]):
        mat[i, j] = dist(i, j)
    if i % 10 == 0:
        print(f"Did {i} out of {df.shape[0]} rows")

plt.figure()
plt.imshow(mat)

np.max(mat)
# Out:
# Did 0 out of 185 rows
# Did 5 out of 185 rows
# Did 10 out of 185 rows
# Did 15 out of 185 rows
# Did 20 out of 185 rows
# Did 25 out of 185 rows
# Did 30 out of 185 rows
# Did 35 out of 185 rows
# Did 40 out of 185 rows
# Did 45 out of 185 rows
# Did 50 out of 185 rows
# Did 55 out of 185 rows
# Did 60 out of 185 rows
# Did 65 out of 185 rows
# Did 70 out of 185 rows
# Did 75 out of 185 rows
# Did 80 out of 185 rows
# Did 85 out of 185 rows
# Did 90 out of 185 rows
# Did 95 out of 185 rows
# Did 100 out of 185 rows
# Did 105 out of 185 rows
# Did 110 out of 185 rows
# Did 115 out of 185 rows
# Did 120 out of 185 rows
# Did 125 out of 185 rows
# Did 130 out of 185 rows
# Did 135 out of 185 rows
# Did 140 out of 185 rows
# Did 145 out of 185 rows
# Did 150 out of 185 rows
# Did 155 out of 185 rows
# Did 160 out of 185 rows
# Did 165 out of 185 rows
# Did 170 out of 185 rows
# Did 175 out of 185 rows
# Did 180 out of 185 rows
# 0.11640359574327451

# %%
from numpy.fft import rfft
from sklearn.manifold import TSNE
    


# cop = deaths_set.copy()
# maxes = np.amax(deaths_set,axis = 1)
# for ind in deaths_set.index:
#     if maxes[ind] != 0:
#         cop.loc[ind, :] /= maxes[ind]

# pre_dat = abs(rfft(cop))
# pre_dat = cop



emb = TSNE(verbose = 1, metric = "precomputed").fit_transform(mat)
# emb = TSNE(verbose = 1).fit_transform(cop)
embed = pd.DataFrame(emb).set_index(deaths_set.index)

embed.to_pickle("embedded.dat")
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 185 samples in 0.002s...
# [t-SNE] Computed neighbors for 185 samples in 0.009s...
# [t-SNE] Computed conditional probabilities for sample 185 / 185
# [t-SNE] Mean sigma: 0.020833
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 55.698544
# [t-SNE] KL divergence after 950 iterations: 0.241249

# %%
# %run interactive_plot.py
# Out:
# <img src="data:image/png;base64,..." width="900">
